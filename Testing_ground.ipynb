# %%
include("const.jl")
include("main.jl")
# Out:
# WARNING: redefinition of constant references. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant targets. This may fail, cause incorrect answers, or produce other errors.
# main (generic function with 1 method)

# %%
ss, staff = main()
# Out:
# 12
# t 1 stock [250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250]
# Production de l'heure : Production([13, 16, 14, 7, 28, 6, 16, 1, 20, 5, 15, 14, 26, 13, 16, 11, 7, 12, 26, 10], 1)
# Demande de l'heure : Signal([13, 16, 14, 7, 28, 6, 16, 1, 20, 5, 15, 14, 26, 13, 16, 11, 7, 12, 26, 10], 1)
# instant t 1 planning employés Any[10, 8, 9, 10, 9, 4]
# taille 12
# t 2 stock [250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250, 250]
# Production de l'heure : Production([10, 4, 28, 6, 29, 5, 1, 23, 13, 11, 2, 7, 3, 4, 19, 24, 17, 28, 27, 23], 1)
# Demande de l'heure : Signal([10, 4, 28, 6, 29, 5, 1, 23, 13, 11, 2, 7, 3, 4, 19, 24, 17, 28, 27, 23], 1)
# instant t 2 planning employés Any[8, 9, 10, 9, 4, 5]
# taille 12
# ...

# %%
include("simulation_plots.jl")
# Out:
# WARNING: redefinition of constant references. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant targets. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant time_frame. This may fail, cause incorrect answers, or produce other errors.
# plot_staffing (generic function with 1 method)

# %%
p1 = plot_stocks(ss, 10)

# %%
p2 = plot_staffing(staff)

# %%
savefig(p1, "stock_plot.png")
savefig(p2, "staff_plot.png")
